# %%
#pandas import
import pandas as pd
#seaborn import
import seaborn as sns
#numpy import
import numpy as np

# %%
#data.Frame 읽어들이기
data=sns.load_dataset('mpg')
#data.Frame을 새로운 파일로 저장하기
import os
#'data'폴더내 'data.csv'파일로 저장
data.to_csv(os.path.join('data/','data.csv'),index=False)
#csv파일 data.Frame 으로 읽어들이기
train=pd.read_csv('data/data.csv')

# %%
#데이터 프레임을 이미지로 변환
# pip install dataframe-image 설치
import dataframe_image as dfi
dataimage=train.loc[10:20:]
#image파일내 dataimage..png파일로 저장
dfi.export(dataimage,'image/dataimage.png')

# %%
#image 파일 가져오기
from PIL import Image
dataimage=Image.open('image/dataimage.png')

# %%
#py파일에서 image파일 저장하기
#index1 내부 참고

# %%
dataimage
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=860x353>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 2>()
#       1 image=Image.open('image/dataimage.png')
# ----> 2 dfi.export(image,'image/image.png')
#
# File ~\miniconda3\lib\site-packages\dataframe_image\_pandas_accessor.py:48, in export(obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi)
#      38 def export(
#      39     obj,
#      40     filename,
#    (...)
#      46     dpi=None
#      47 ):
# ---> 48     return _export(
#      49         obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi
#      50    )
#
# File ~\miniconda3\lib\site-packages\dataframe_image\_pandas_accessor.py:74, in _export(obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi)
#      68     from ._matplotlib_table import TableMaker
#      70     converter = TableMaker(
#      71         fontsize=fontsize, encode_base64=False, for_document=False, savefig_dpi=dpi
#      72     ).run
# ---> 74 if df.shape[0] > MAX_ROWS and max_rows is None:
#      75     error_msg = (
#      76         f"Your DataFrame has more than {MAX_ROWS} rows and will produce a huge "
#      77         "image file, possibly causing your computer to crash. Override this error "
#      78         "by explicitly setting `max_rows`. Use -1 for all rows."
#      79     )
#      80     if is_styler:
#
# File ~\miniconda3\lib\site-packages\PIL\Image.py:517, in Image.__getattr__(self, name)
#     515     deprecate("Image categories", 10, "is_animated", plural=True)
#     516     return self._category
# --> 517 raise AttributeError(name)
#
# AttributeError: shape
