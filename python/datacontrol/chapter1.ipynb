# %%
#라이브러리 불러오기 (import) import pandas
import pandas as pd
import seaborn as sns

# %%
#파일 불러오기 (read_csv()) read vegitable.csv in datafile
vegitable=pd.read_csv('datafile\\vegitable.csv')
vegitable
# Out:
#      지역  엽채류 노지 면적  엽채류 노지 생산량  엽채류 시설 면적  엽채류 시설 생산량  고랭지배추 노지 면적  \
# 0   서 울        112         846         62         912            0
# 1   부 산        338       18105        291        9569            0
# 2   대 구        171       11414        238        8298            0
# 3   인 천        228       19682        180        5544            0
# 4   광 주        191       18357        146        5486            0
# 5   대 전         89        8693         18         461            0
# 6   울 산        330       22685        194        6248            0
# 7   경 기       2505      220367       4440      125250            0
# 8   강 원       7713      365880        192        5445         5099
# 9   충 북       2757      205887        263        7767            0
# 10  충 남       2398      200402       1052       39116            0
# 11  전 북       2579      209753        684       23557          195
# 12  전 남      10315      743502        627       24352            0
# ...

# %%
#파이썬 행 열 갯수 관찰하기(shape) using shape
vegitable.shape
# Out:
# (17, 47)

# %%
#데이터 확인하기 (head())
vegitable.head(10)
# Out:
#     지역  엽채류 노지 면적  엽채류 노지 생산량  엽채류 시설 면적  엽채류 시설 생산량  고랭지배추 노지 면적  \
# 0  서 울        112         846         62         912            0
# 1  부 산        338       18105        291        9569            0
# 2  대 구        171       11414        238        8298            0
# 3  인 천        228       19682        180        5544            0
# 4  광 주        191       18357        146        5486            0
# 5  대 전         89        8693         18         461            0
# 6  울 산        330       22685        194        6248            0
# 7  경 기       2505      220367       4440      125250            0
# 8  강 원       7713      365880        192        5445         5099
# 9  충 북       2757      205887        263        7767            0
#
#    고랭지배추 노지 단수  고랭지배추 노지 생산량  가을배추 노지 면적  가을배추 노지단수  ...  쑥갓 노지 생산량  쑥갓 시설 면적  \
# 0            0             0          11       7440  ...          0        56
# 1            0             0          99      10360  ...         15         9
# ...

# %%
train=pd.read_csv('datafile\\train.csv')
train
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 2        7     6                  13.9                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# ...    ...   ...                   ...                     ...
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                    1.5               89.0                576.0
# 1                    1.4               48.0                916.0
# ...

# %%
train.shape
# Out:
# (1459, 11)

# %%
train.head(10)
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   3    20                  16.3                     1.0                 1.5
# 1   6    13                  20.1                     0.0                 1.4
# 2   7     6                  13.9                     0.0                 0.7
# 3   8    23                   8.1                     0.0                 2.7
# 4   9    18                  29.5                     0.0                 4.8
# 5  13     2                  13.6                     0.0                 1.7
# 6  14     3                  10.6                     0.0                 1.5
# 7  16    21                  16.0                     0.0                 6.0
# 8  19     9                  13.8                     0.0                 1.9
# 9  20    14                  17.2                     0.0                 2.1
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# ...

# %%
sns.pairplot(data=train)

# %%
train.corr()
train
#시간 기온 강수량 풍속 습도 가시거리 오존
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 0        3    20                  16.3                     1.0
# 1        6    13                  20.1                     0.0
# 2        7     6                  13.9                     0.0
# 3        8    23                   8.1                     0.0
# 4        9    18                  29.5                     0.0
# ...    ...   ...                   ...                     ...
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 0                    1.5               89.0                576.0
# 1                    1.4               48.0                916.0
# ...

# %%
sns.scatterplot(data=train, y="count",x='hour_bef_temperature')
# Out:
# <AxesSubplot:xlabel='hour_bef_temperature', ylabel='count'>

# %%
sns.boxplot(data=train, y='count',x='hour_bef_precipitation')
# Out:
# <AxesSubplot:xlabel='hour_bef_precipitation', ylabel='count'>

# %%
#1point need 1 hour
#10	10	[[10,15,2,1,2],[20,20,3,3,4]]	                     15

#0	0	[[0,0,2,1,2],[4,5,3,1,2],[4,11,4,0,2],[10,4,0,4,2]]	 13

# %%
arr=[[0,0,2,1,2],[4,5,3,1,2],[4,11,4,0,2],[10,4,0,4,2]]
arr.sort(key=lambda x : (x[0]))
print(arr)
arr.sort(key=lambda x : (x[1]))
print(arr)
arr.sort(key=lambda x : (x[2]))
print(arr)
# Out:
# [[0, 0, 2, 1, 2], [4, 5, 3, 1, 2], [4, 11, 4, 0, 2], [10, 4, 0, 4, 2]]
# [[0, 0, 2, 1, 2], [10, 4, 0, 4, 2], [4, 5, 3, 1, 2], [4, 11, 4, 0, 2]]
# [[10, 4, 0, 4, 2], [0, 0, 2, 1, 2], [4, 5, 3, 1, 2], [4, 11, 4, 0, 2]]

# %%
#10	10	[[10,15,2,1,2],[20,20,3,3,4]]	                     15
arrs=[[0,0,2,1,2],[0,5,3,1,2],[4,0,4,0,2],[0,1,0,4,2],[7,2,1,2,4]]
alp=0
cop=0
talp=max(max(arrs,key=lambda x:x[0]))#10
tcop=max(max(arrs,key=lambda x:x[1]))#11
arrs.sort()
for i in range(len(arrs)):
    arrs[i].append((arrs[i][2]+arrs[i][3])/arrs[i][4])
    if arrs[i][5]<=1:
        arrs.pop(i)
print(arrs)
#가능한 배열 찾기
count=0
for i in range(10):
    alp=alp+3
    cop+=2
    count+=1
    if alp>=talp & cop>=tcop:
        break
print(alp,cop)
print(count)
# Out:
# [[0, 0, 2, 1, 2, 1.5], [0, 1, 0, 4, 2, 2.0], [0, 5, 3, 1, 2, 2.0], [4, 0, 4, 0, 2, 2.0]]
# 9 6
# 3

# %%
arrs=[[0,0,2,1,2],[0,0,3,1,2],[0,0,4,0,2],[0,0,0,4,2],[7,5,1,2,4]]
#arr=>1번 perH 2번 nTime
arr1=[[1.5,5],[2,5],[2,2],[2,2],[0.75,7]]#-1은 무한
#1실행후 필요수치 4,4
arr2=[[1.5,4],[2,4],[2,1],[2,1],[0.75,4]]
#실제 3 2 1 행하다면 complete

#if 7,5

# %%
#[5,3],[3,10],[10,6
#수로 치면 5 3 10 6
#15 30 60
#180 90 10 6 3 [15,50,9,30 ]
a=5*3*10
b=3*10*6
print(a)
print(b)
print(5*3*10*6)
#answer=450 150+300[3 10 6]v[6 3 5][3 3 10]v
# Out:
# 150
# 180
# 900

# %%
arrs=[[5,3],[3,10]]
arrs1=[]
count=0
for i in range(len(arrs)):
    for j in range(len(arrs[i])):
        print(arrs[i][j])
# Out:
# 5
# 3
# 3
# 10
