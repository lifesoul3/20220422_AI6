# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print(pd.__version__)
print(sns.__version__)
# Out:
# 1.4.4
# 0.12.0

# %%
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/raw/mpg.csv
# DataFrame
df=sns.load_dataset("mpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 # https://raw.githubusercontent.com/mwaskom/seaborn-data/master/raw/mpg.csv
#       2 # DataFrame
# ----> 3 df=sns.load_dataset("mpg")
#
# NameError: name 'sns' is not defined

# %%
# head()=>가장 위에서 기본5개를 가지고온다
# tail()=>가장 끝에서 기본5개를 가지고온다
# sample()=>랜덤으로 기본1개를 가지고온다
df.head(10)
df.tail(10)
df.sample(10)
# seed값을 통한 random 고정
df.sample(3,random_state=42)
#shift+tab
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       1 # head()=>가장 위에서 기본5개를 가지고온다
#       2 # tail()=>가장 끝에서 기본5개를 가지고온다
#       3 # sample()=>랜덤으로 기본1개를 가지고온다
# ----> 4 df.head(10)
#       5 df.tail(10)
#       6 df.sample(10)
#
# NameError: name 'df' is not defined

# %%
#datainfo
#origin 1=USA 2=europ 3=japan
#mpg외의 자료를 토대로 mpg값을 산출하라
df.index
df.columns
df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df=sns.load_dataset('mpg')
df.info()
#horsepower부분에 자료가 빠진 상황=>결측치
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
#결측치 비율 확인
df.isnull().mean()*100
df.describe()
#std 표준편차의 중요성
#표준편차에서 벗어난 값은 사실상 데이터로서 가치가 없다고 판단할 수 있음
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
sns.regplot(y='horsepower',x='weight',data=df)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='horsepower'>

# %%
sns.regplot(x='cylinders',y='displacement',data=df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
# Out:
# lets find an old website.
# type a website url: lolcats.com
